# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
demo = pd.read_csv("Laliga.csv")   #load the data
demo.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0        Pos             Team    Seasons     Points  GamesPlayed   GamesWon
# 1          1      Real Madrid         86       4385         2762       1647
# 2          2        Barcelona         86       4262         2762       1581
# 3          3  Atletico Madrid         80       3442         2614       1241
# 4          4         Valencia         82       3386         2664       1187
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0  GamesDrawn  GamesLost   GoalsFor  GoalsAgainst    Champion   Runner-up
# 1         552        563       5947          3140          33          23
# 2         573        608       5900          3114          25          25
# 3         598        775       4534          3309          10           8
# 4         616        861       4398          3469           6           6
#
# ...

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 20 columns):
# Unnamed: 0     62 non-null object
# Unnamed: 1     62 non-null object
# Unnamed: 2     62 non-null object
# Unnamed: 3     62 non-null object
# Unnamed: 4     62 non-null object
# Unnamed: 5     62 non-null object
# Unnamed: 6     62 non-null object
# Unnamed: 7     62 non-null object
# Unnamed: 8     62 non-null object
# Unnamed: 9     62 non-null object
# Unnamed: 10    62 non-null object
# Unnamed: 11    62 non-null object
# Unnamed: 12    62 non-null object
# Unnamed: 13    62 non-null object
# Unnamed: 14    62 non-null object
# Unnamed: 15    62 non-null object
# Unnamed: 16    62 non-null object
# Unnamed: 17    62 non-null object
# Unnamed: 18    62 non-null object
# Unnamed: 19    62 non-null object
# dtypes: object(20)
# memory usage: 9.8+ KB

# %%
demo.describe(include="all")
# Out:
#        Unnamed: 0           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# count          62                   62         62         62         62
# unique         62                   62         34         62         54
# top            37  Deportivo La Coruna          1       1789       2762
# freq            1                    1          6          1          3
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# count          62         62         62         62         62          62
# unique         60         58         57         61         62           9
# top             8         44         37         70        115           -
# freq            2          2          3          2          1          52
#
#        Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# count           62          62          62          62          62
# unique          11          10          10          10          10
# ...

# %%
newcolumn = demo.iloc[0]
df = demo[1:]           #replace the column name
df.columns = newcolumn
df.head()
df.reset_index(drop=True, inplace=True)       # Reset to default index value instead of A to J
df.head()
# Out:
# 0 Pos             Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0   1      Real Madrid      86   4385        2762     1647        552
# 1   2        Barcelona      86   4262        2762     1581        573
# 2   3  Atletico Madrid      80   3442        2614     1241        598
# 3   4         Valencia      82   3386        2664     1187        616
# 4   5  Athletic Bilbao      86   3368        2762     1209        633
#
# 0 GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# 1       608     5900         3114       25        25    12     12     4     6
# 2       775     4534         3309       10         8    16      9     7     6
# 3       861     4398         3469        6         6    10     11    10     7
# 4       920     4631         3700        8         7    10      5     8    10
#
# 0   T    Debut Since/LastApp BestPosition
# ...

# %%
df.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut',
#        'Since/LastApp', 'BestPosition'],
#       dtype='object', name=0)

# %%
###Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data. (2.5 points)
         #question1
df.replace('-', '0', inplace=True)        ##demo.fillna(value=0)    for fill nan value with zero    
df                                       ## demo.dropna()        for dropping columns with nan values
# Out:
# C:\Users\AMIT\Anaconda3\lib\site-packages\pandas\core\frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
# 0  Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0    1          Real Madrid      86   4385        2762     1647        552
# 1    2            Barcelona      86   4262        2762     1581        573
# 2    3      Atletico Madrid      80   3442        2614     1241        598
# 3    4             Valencia      82   3386        2664     1187        616
# 4    5      Athletic Bilbao      86   3368        2762     1209        633
# 5    6              Sevilla      73   2819        2408      990        531
# 6    7             Espanyol      82   2792        2626      948        608
# ...

# %%
2###Print all the teams which have started playing between 1930-1980. (5 points)
df_year = df[(df['Debut'] > '1930')& (df['Debut'] < '1980')]     #first method
df_year.head()
# Out:
# 0  Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 3    4             Valencia      82   3386        2664     1187        616
# 5    6              Sevilla      73   2819        2408      990        531
# 8    9             Zaragoza      58   2109        1986      698        522
# 9   10           Real Betis      51   1884        1728      606        440
# 10  11  Deportivo La Coruna      45   1814        1530      563        392
#
# 0  GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# 3        861     4398         3469        6         6    10     11    10
# 5        887     3680         3373        1         4     4      5    12
# 8        766     2683         2847        0         1     4      5     4
# 9        682     2159         2492        1         0     2      3     4
# 10       575     2052         2188        1         5     4      1     0
#
# 0  Sixth   T    Debut Since/LastApp BestPosition
# ...

# %%
2###all the teams which have started playing between 1930-1980. (5 points)

df_year = df.loc[(df['Debut'] >= '1930') & (df['Debut'] <'1980')]    #second method
df_year.head()
# Out:
# 0  Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 3    4             Valencia      82   3386        2664     1187        616
# 5    6              Sevilla      73   2819        2408      990        531
# 8    9             Zaragoza      58   2109        1986      698        522
# 9   10           Real Betis      51   1884        1728      606        440
# 10  11  Deportivo La Coruna      45   1814        1530      563        392
#
# 0  GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# 3        861     4398         3469        6         6    10     11    10
# 5        887     3680         3373        1         4     4      5    12
# 8        766     2683         2847        0         1     4      5     4
# 9        682     2159         2492        1         0     2      3     4
# 10       575     2052         2188        1         5     4      1     0
#
# 0  Sixth   T    Debut Since/LastApp BestPosition
# ...

# %%
2###Print all the teams which have started playing between 1930-1980. (5 points)

df_year= df.loc[:][(df['Debut'] > '1930') & (df['Debut'] < '1980')]   #third method
df_year.head()
# Out:
# 0  Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 3    4             Valencia      82   3386        2664     1187        616
# 5    6              Sevilla      73   2819        2408      990        531
# 8    9             Zaragoza      58   2109        1986      698        522
# 9   10           Real Betis      51   1884        1728      606        440
# 10  11  Deportivo La Coruna      45   1814        1530      563        392
#
# 0  GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# 3        861     4398         3469        6         6    10     11    10
# 5        887     3680         3373        1         4     4      5    12
# 8        766     2683         2847        0         1     4      5     4
# 9        682     2159         2492        1         0     2      3     4
# 10       575     2052         2188        1         5     4      1     0
#
# 0  Sixth   T    Debut Since/LastApp BestPosition
# ...

# %%
df['Points'].head()
# Out:
# 0    4385
# 1    4262
# 2    3442
# 3    3386
# 4    3368
# Name: Points, dtype: object

# %%
3###Print the list of teams which came Top 5 in terms of points 
point= df[['Team','Points']]

point.head()
# Out:
# 0             Team Points
# 0      Real Madrid   4385
# 1        Barcelona   4262
# 2  Atletico Madrid   3442
# 3         Valencia   3386
# 4  Athletic Bilbao   3368

# %%
3###Print the list of teams which came Top 5 in terms of points 

df.loc[:4],['Team','Points']
# Out:
# (0 Pos             Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
#  0   1      Real Madrid      86   4385        2762     1647        552
#  1   2        Barcelona      86   4262        2762     1581        573
#  2   3  Atletico Madrid      80   3442        2614     1241        598
#  3   4         Valencia      82   3386        2664     1187        616
#  4   5  Athletic Bilbao      86   3368        2762     1209        633
#
#  0 GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
#  0       563     5947         3140       33        23     8      8     3     4
#  1       608     5900         3114       25        25    12     12     4     6
#  2       775     4534         3309       10         8    16      9     7     6
#  3       861     4398         3469        6         6    10     11    10     7
#  4       920     4631         3700        8         7    10      5     8    10
#
#  0   T    Debut Since/LastApp BestPosition
# ...

# %%
df.dtypes
# Out:
# 0
# Pos              object
# Team             object
# Seasons          object
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition     object
# dtype: object

# %%
df['Points '] = df.Points.astype(int)    #change data types into integer
# Out:
# C:\Users\AMIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Points '].dtypes
# Out:
# dtype('int32')

# %%
3###Print the list of teams which came Top 5 in terms of points 
df.sort_values(by =["Points"],ascending=False, kind='quicksort')
df[['Team','Points']].iloc[0:5]
#point.sort_values(by= 'Points').head()           #both gives the same result
# Out:
# 0             Team Points
# 0      Real Madrid   4385
# 1        Barcelona   4262
# 2  Atletico Madrid   3442
# 3         Valencia   3386
# 4  Athletic Bilbao   3368

# %%
print(df['GoalsFor'].dtypes)       #solution for question 4 start here
# Out:
# object

# %%
df['GoalsAgainst'].dtypes
# Out:
# dtype('O')

# %%
df['GoalsFor'] = df.GoalsFor.astype(int)     ### convert datatype into integer
# Out:
# C:\Users\AMIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['GoalsFor'].dtypes
# Out:
# dtype('int32')

# %%
df['GoalsAgainst'] = df.GoalsAgainst.astype(int)        ### convert datatype into integer
# Out:
# C:\Users\AMIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['GoalsAgainst'].dtypes
# Out:
# dtype('int32')

# %%
GoalsFor= df['GoalsFor']
GoalsFor.head()
# Out:
# 0    5947
# 1    5900
# 2    4534
# 3    4398
# 4    4631
# Name: GoalsFor, dtype: int32

# %%
GoalsAgainst=df['GoalsAgainst']
GoalsAgainst.head()
# Out:
# 0    3140
# 1    3114
# 2    3309
# 3    3469
# 4    3700
# Name: GoalsAgainst, dtype: int32

# %%
4##Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences
def Goal_diff_count(GoalsFor,GoalsAgainst):
    return (GoalsFor-GoalsAgainst)

# %%
Goal_diff_count(GoalsFor,GoalsAgainst).head()        ### “Goal_diff_count”
# Out:
# 0    2807
# 1    2786
# 2    1225
# 3     929
# 4     931
# dtype: int32

# %%
#newindex = Goal_diff_count
#df['Goal_diff_count'] = newindex
#df
df["Goal_diff_count"]=df['GoalsFor']-df['GoalsAgainst']
df.head()
# Out:
# C:\Users\AMIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 0 Pos             Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0   1      Real Madrid      86   4385        2762     1647        552
# 1   2        Barcelona      86   4262        2762     1581        573
# 2   3  Atletico Madrid      80   3442        2614     1241        598
# 3   4         Valencia      82   3386        2664     1187        616
# 4   5  Athletic Bilbao      86   3368        2762     1209        633
#
# 0 GamesLost  GoalsFor  GoalsAgainst  ... Third Fourth Fifth Sixth   T  \
# 0       563      5947          3140  ...     8      8     3     4  79
# ...

# %%
def Goal_diff_max(GoalsFor,GoalsAgainst):                   ###maximum goal difference.
    return max(GoalsFor-GoalsAgainst)

# %%
Goal_diff_max(GoalsFor,GoalsAgainst)
# Out:
# 2807

# %%
def Goal_diff_min(GoalsFor,GoalsAgainst):                ###minimum goal difference.
    return min(GoalsFor-GoalsAgainst)

# %%
Goal_diff_min(GoalsFor,GoalsAgainst)
# Out:
# -525

# %%
df['GamesWon'] = df.GamesWon.astype(int)        #solution for question 5 start here
df['GamesWon'].head()

                                               ### convert datatype into integer
# Out:
# C:\Users\AMIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0    1647
# 1    1581
# 2    1241
# 3    1187
# 4    1209
# Name: GamesWon, dtype: int32

# %%
df['GamesPlayed'] = df.GamesPlayed.astype(int)  
df['GamesPlayed'].head()                                     ### convert datatype into integer
# Out:
# C:\Users\AMIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0    2762
# 1    2762
# 2    2614
# 3    2664
# 4    2762
# Name: GamesPlayed, dtype: int32

# %%
a = df['GamesWon']
a.head()
# Out:
# 0    1647
# 1    1581
# 2    1241
# 3    1187
# 4    1209
# Name: GamesWon, dtype: int32

# %%
b = df['GamesPlayed']
b.head()
# Out:
# 0    2762
# 1    2762
# 2    2614
# 3    2664
# 4    2762
# Name: GamesPlayed, dtype: int32

# %%
df["PercentageofWinning"]=100*(df['GamesWon']/df['GamesPlayed'])        ##first method
df[['PercentageofWinning','Team']].head()
# Out:
# C:\Users\AMIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0  PercentageofWinning             Team
# 0            59.630702      Real Madrid
# 1            57.241130        Barcelona
# 2            47.475134  Atletico Madrid
# 3            44.557057         Valencia
# 4            43.772629  Athletic Bilbao

# %%
PercentageofWinning = (a/ b)*100             ###second method
PercentageofWinning.head()
# Out:
# 0    59.630702
# 1    57.241130
# 2    47.475134
# 3    44.557057
# 4    43.772629
# dtype: float64

# %%
def PercentageofWinning(a,b):                ###maximum goal difference.
    return (a/b) * 100                       ###third method

# %%
PercentageofWinning(a,b).head()
# Out:
# 0    59.630702
# 1    57.241130
# 2    47.475134
# 3    44.557057
# 4    43.772629
# dtype: float64

# %%
6###Group teams based on their “Best position” and print the sum of their points for all positions
df.head()
# Out:
# 0 Pos             Team Seasons Points  GamesPlayed  GamesWon GamesDrawn  \
# 0   1      Real Madrid      86   4385         2762      1647        552
# 1   2        Barcelona      86   4262         2762      1581        573
# 2   3  Atletico Madrid      80   3442         2614      1241        598
# 3   4         Valencia      82   3386         2664      1187        616
# 4   5  Athletic Bilbao      86   3368         2762      1209        633
#
# 0 GamesLost  GoalsFor  GoalsAgainst  ... Fourth Fifth Sixth   T    Debut  \
# 0       563      5947          3140  ...      8     3     4  79     1929
# 1       608      5900          3114  ...     12     4     6  83     1929
# 2       775      4534          3309  ...      9     7     6  56     1929
# 3       861      4398          3469  ...     11    10     7  50  1931-32
# 4       920      4631          3700  ...      5     8    10  49     1929
#
# 0 Since/LastApp BestPosition Points   \
# 0          1929            1    4385
# ...

# %%
df.groupby("BestPosition").sum()
# Out:
# 0             GamesPlayed  GamesWon  GoalsFor  GoalsAgainst  Points   \
# BestPosition
# 1                   21532      9888     36529         28015    27933
# 10                    450       134       554           776      450
# 11                    586       145       607           992      445
# 12                    652       163       609           972      511
# 14                     90        29       121           183       71
# 15                     30         5        34            65       14
# 16                    128        27       158           324       81
# 17                    270        65       253           425      266
# 19                     80        19        70           115       81
# 2                    6614      2255      8518          9902     6904
# 20                     38         8        38            66       34
# 3                    4936      1732      6660          7519     5221
# ...
